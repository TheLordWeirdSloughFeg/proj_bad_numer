# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Po kolei sprawdzam aktorów, aktorki, reżysreów i kompozytorów z top 500 Filmwebu

# %%
aktorzy = pd.read_csv('aktorzy_tabelka.txt')

# %%
aktorzy.head(10)
# Out:
#    Unnamed: 0    Imie_i_Nazwisko  dzien  miesiac   rok  liczba urodzenia  \
# 0           0    Joaquin_Phoenix     28       10  1974                 5
# 1           1     Jack_Nicholson     22        4  1937                 1
# 2           2  Leonardo_DiCaprio     11       11  1974                 7
# 3           3          Al_Pacino     25        4  1940                 7
# 4           4     Clint_Eastwood     31        5  1930                22
# 5           5       Alan_Rickman     21        2  1946                 7
# 6           6    Anthony_Hopkins     31       12  1937                 9
# 7           7  Robert_Downey_Jr.      4        4  1965                11
# 8           8          Tom_Hanks      9        7  1956                 1
# 9           9          Joe_Pesci      9        2  1943                 1
#
#   znak zodiaku  liczba imienia i nazwiska
# 0     skorpion                          7
# 1          byk                          8
# ...

# %%
aktorzy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 500 non-null    int64
#  1   Imie_i_Nazwisko            500 non-null    object
#  2   dzien                      500 non-null    int64
#  3   miesiac                    500 non-null    int64
#  4   rok                        500 non-null    int64
#  5   liczba urodzenia           500 non-null    int64
#  6   znak zodiaku               500 non-null    object
#  7   liczba imienia i nazwiska  500 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 31.4+ KB

# %%
#Sprawdzam jaki jest rozkład odpowiednich kolumndla aktorek
aktorzy.drop('Unnamed: 0', axis = 1).hist(bins=60, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
aktorki = pd.read_csv('aktorki_tabelka.txt')

# %%
aktorki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 477 non-null    int64
#  1   Imie_i_Nazwisko            477 non-null    object
#  2   dzien                      477 non-null    int64
#  3   miesiac                    477 non-null    int64
#  4   rok                        477 non-null    int64
#  5   liczba urodzenia           477 non-null    int64
#  6   znak zodiaku               477 non-null    object
#  7   liczba imienia i nazwiska  477 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 29.9+ KB

# %%
#Sprawdzam jaki jest rozkład odpowiednich kolumn dla aktorek
aktorki.drop('Unnamed: 0', axis = 1).hist(bins=60, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
reżyserzy = pd.read_csv('reżyserzy_tabelka.txt')

# %%
reżyserzy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 181 non-null    int64
#  1   Imie_i_Nazwisko            181 non-null    object
#  2   dzien                      181 non-null    int64
#  3   miesiac                    181 non-null    int64
#  4   rok                        181 non-null    int64
#  5   liczba urodzenia           181 non-null    int64
#  6   znak zodiaku               181 non-null    object
#  7   liczba imienia i nazwiska  181 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 11.4+ KB

# %%
#Sprawdzam jaki jest rozkład odpowiednich kolulm dla reżyserów
reżyserzy.drop('Unnamed: 0', axis = 1).hist(bins=60, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
kompozytorzy = pd.read_csv('kompozytorzy_tabelka.txt')

# %%
kompozytorzy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 157 non-null    int64
#  1   Imie_i_Nazwisko            157 non-null    object
#  2   dzien                      157 non-null    int64
#  3   miesiac                    157 non-null    int64
#  4   rok                        157 non-null    int64
#  5   liczba urodzenia           157 non-null    int64
#  6   znak zodiaku               157 non-null    object
#  7   liczba imienia i nazwiska  157 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 9.9+ KB

# %%
#Sprawdzam jaki jest rozkład odpowiednich kolulm dla kompozytorów
kompozytorzy.drop('Unnamed: 0', axis = 1).hist(bins=60, figsize=(12,8))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Wstepne wnioski

# %% [markdown]
# W przypadku aktorów i aktorek najczęstszym miesiącem urodzenia jest kwiecień (znak zodiaku baran), a najczęstszą liczbą urodzenia jest 9
#
# W przypadku reżyserów najczęstszą liczbą urodzenia jest 7, miesiącem urodzenia marzec (znak zodiaku ryby), a najczęstszą liczbą imienia i nazwiska 11 oraz 9.
#
# W przypadku kompozytorów najczęstszą liczbą urodzenia jest również 9, a najczęstsza liczba imienia i nazwiska to 1 i 11. Najwięcej kompozytorów urodziło się w marcu i kwietniu (znak zodiaku baran oraz byk).

# %% [markdown]
# ### Połączone tabele wszystkich ludzi filmu
# ##### Dodana ostatnia kolumna zawiera zakodowane profesje
# * 1 to aktorzy i aktorki
# * 2 to reżyserzy
# * 3 to kompozytorzy

# %%
data = pd.read_csv('ludzie_filmu.txt')

# %%
#data['liczba urodzenia'].value_counts()

# %%
#data['miesiac'].value_counts()

# %%
#data['rok'].value_counts()

# %%
#data['dzien'].value_counts()

# %%
#data['liczba imienia i nazwiska'].value_counts()

# %%
#data['znak zodiaku'].value_counts()

# %%
data.head(10)
# Out:
#    Unnamed: 0    Imie_i_Nazwisko  dzien  miesiac   rok  liczba urodzenia  \
# 0           0    Joaquin_Phoenix     28       10  1974                 5
# 1           1     Jack_Nicholson     22        4  1937                 1
# 2           2  Leonardo_DiCaprio     11       11  1974                 7
# 3           3          Al_Pacino     25        4  1940                 7
# 4           4     Clint_Eastwood     31        5  1930                22
# 5           5       Alan_Rickman     21        2  1946                 7
# 6           6    Anthony_Hopkins     31       12  1937                 9
# 7           7  Robert_Downey_Jr.      4        4  1965                11
# 8           8          Tom_Hanks      9        7  1956                 1
# 9           9          Joe_Pesci      9        2  1943                 1
#
#   znak zodiaku  liczba imienia i nazwiska  profesja
# 0     skorpion                          7         1
# 1          byk                          8         1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1315 entries, 0 to 1314
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 1315 non-null   int64
#  1   Imie_i_Nazwisko            1315 non-null   object
#  2   dzien                      1315 non-null   int64
#  3   miesiac                    1315 non-null   int64
#  4   rok                        1315 non-null   int64
#  5   liczba urodzenia           1315 non-null   int64
#  6   znak zodiaku               1315 non-null   object
#  7   liczba imienia i nazwiska  1315 non-null   int64
#  8   profesja                   1315 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 92.6+ KB

# %%
#Sprawdzam jaki jest rozkład odpowiednich kolumn
data.drop('Unnamed: 0', axis = 1).hist(bins=60, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
DB = data.dropna(axis=0)
DB.head(10)
# Out:
#    Unnamed: 0    Imie_i_Nazwisko  dzien  miesiac   rok  liczba urodzenia  \
# 0           0    Joaquin_Phoenix     28       10  1974                 5
# 1           1     Jack_Nicholson     22        4  1937                 1
# 2           2  Leonardo_DiCaprio     11       11  1974                 7
# 3           3          Al_Pacino     25        4  1940                 7
# 4           4     Clint_Eastwood     31        5  1930                22
# 5           5       Alan_Rickman     21        2  1946                 7
# 6           6    Anthony_Hopkins     31       12  1937                 9
# 7           7  Robert_Downey_Jr.      4        4  1965                11
# 8           8          Tom_Hanks      9        7  1956                 1
# 9           9          Joe_Pesci      9        2  1943                 1
#
#   znak zodiaku  liczba imienia i nazwiska  profesja
# 0     skorpion                          7         1
# 1          byk                          8         1
# ...

# %%
DBB=DB.replace({"znak zodiaku":{"brak":0,"baran": 1, "byk": 2, "bliznieta": 3,"rak": 4,"lew": 5, "panna": 6, "waga": 7 ,
                                "skorpion": 8, "strzelec": 9, "koziorozec": 10, "wodnik": 11, "ryby": 12}})

DBB.head(10)
# Out:
#    Unnamed: 0    Imie_i_Nazwisko  dzien  miesiac   rok  liczba urodzenia  \
# 0           0    Joaquin_Phoenix     28       10  1974                 5
# 1           1     Jack_Nicholson     22        4  1937                 1
# 2           2  Leonardo_DiCaprio     11       11  1974                 7
# 3           3          Al_Pacino     25        4  1940                 7
# 4           4     Clint_Eastwood     31        5  1930                22
# 5           5       Alan_Rickman     21        2  1946                 7
# 6           6    Anthony_Hopkins     31       12  1937                 9
# 7           7  Robert_Downey_Jr.      4        4  1965                11
# 8           8          Tom_Hanks      9        7  1956                 1
# 9           9          Joe_Pesci      9        2  1943                 1
#
#    znak zodiaku  liczba imienia i nazwiska  profesja
# 0             8                          7         1
# 1             2                          8         1
# ...

# %%
#tsv_data = pd.read_csv('D://Papierkowa robota//PJA//Projekty własny -numerologia//data.tsv', sep='\t')
#tsv_data.head(20)

# %%
x = DBS.iloc[:,[2,3,4,5,6,7,8]]

# %%
#x = xx[~(xx == 0).any(axis=1)]

# %%
x['znak zodiaku'].value_counts()
# Out:
# 1     138
# 5     125
# 12    120
# 9     115
# 2     115
# 7     108
# 4     107
# 10     99
# 3      99
# 6      96
# 11     88
# 8      87
# 0      18
# Name: znak zodiaku, dtype: int64

# %%
#print (x.dtypes)

# %%
x.shape
# Out:
# (1315, 7)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1315 entries, 0 to 1314
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   dzien                      1315 non-null   int64
#  1   miesiac                    1315 non-null   int64
#  2   rok                        1315 non-null   int64
#  3   liczba urodzenia           1315 non-null   int64
#  4   znak zodiaku               1315 non-null   int64
#  5   liczba imienia i nazwiska  1315 non-null   int64
#  6   profesja                   1315 non-null   int64
# dtypes: int64(7)
# memory usage: 122.2 KB

# %%
sns.set_style("whitegrid");
sns.FacetGrid(x, hue="profesja", height=7).map(plt.scatter, "liczba imienia i nazwiska", "liczba urodzenia").add_legend();
plt.show()

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(x, hue="profesja", height=3);
plt.show()

# %%
X=x.iloc[:,:-1]
Y=x['profesja']

# %%
import shap
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X.values,Y.values,test_size=0.25,random_state=50)

# %%
booster = xgb.XGBRegressor(colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=6, n_estimators=100, random_state=4)


booster.fit(X_train, y_train)

y_pred_train = booster.predict(X_train)
y_pred_test = booster.predict(X_test)

# %%
#Sprawdzam jake czynniki mają wpływ na profesję (o ile jakiekolwiek)

# %%
explainer = shap.TreeExplainer(booster)
shap_values = explainer.shap_values(X)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
feat_importances = pd.Series(booster.feature_importances_, index=X.columns)
feat_importances.nlargest(15).sort_values().plot(kind='barh', color='darkblue', figsize=(10,5))
plt.xlabel('Relative Feature Importance with XGBoost')
# Out:
# Text(0.5, 0, 'Relative Feature Importance with XGBoost')

# %%
shap.summary_plot(shap_values, X, plot_type="bar")

# %%
from xgboost.sklearn import XGBClassifier
model=XGBClassifier(eta=0.1,min_child_weight=1,n_estimators=100)

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eta=0.1, gamma=0,
#               gpu_id=-1, importance_type='gain', interaction_constraints='',
#               learning_rate=0.100000001, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
from sklearn import metrics
print("Accuracy")
print( round(metrics.accuracy_score(y_test, model.predict(X_test))*100,0),'%')
# Out:
# Accuracy
# 68.0 %

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_loop = np.arange(1,35)
k_scores = []
from sklearn.model_selection import cross_val_score

# %%
for k in k_loop:
    knn = KNeighborsClassifier(n_neighbors=k)
    cross_val = cross_val_score(knn, X_train, y_train, cv=10 , scoring='accuracy')
    k_scores.append(cross_val.mean())

# %%
plt.style.use('fivethirtyeight')
plt.plot(k_loop, k_scores)
plt.show()

# %%
# Wybrałem 16

# %%
KNN_model=KNeighborsClassifier(n_neighbors=16)
KNN_model.fit(X_train,y_train)
y_train_predict = KNN_model.predict(X_train)
KNN_model_score = KNN_model.score(X_train, y_train)

# %%
print("Wynik modelu to " + str(round(KNN_model_score*100, 2)) +" %")
# Out:
# Wynik modelu to 75.96 %
